# %% [markdown]
# Something is wrong with global snow production, and you've been selected to take a look. The Elves have even given you a map; on it, they've used stars to mark the top fifty locations that are likely to be having problems.
#
# You've been doing this long enough to know that to restore snow operations, you need to check all fifty stars by December 25th.
#
# Collect stars by solving puzzles. Two puzzles will be made available on each day in the Advent calendar; the second puzzle is unlocked when you complete the first. Each puzzle grants one star. Good luck!
#
# You try to ask why they can't just use a weather machine ("not powerful enough") and where they're even sending you ("the sky") and why your map looks mostly blank ("you sure ask a lot of questions") and hang on did you just say the sky ("of course, where do you think snow comes from") when you realize that the Elves are already loading you into a trebuchet ("please hold still, we need to strap you in").
#
# As they're making the final adjustments, they discover that their calibration document (your puzzle input) has been amended by a very young Elf who was apparently just excited to show off her art skills. Consequently, the Elves are having trouble reading the values on the document.
#
# The newly-improved calibration document consists of lines of text; each line originally contained a specific calibration value that the Elves now need to recover. On each line, the calibration value can be found by combining the first digit and the last digit (in that order) to form a single two-digit number.
#
# For example:
#
# 1abc2
#
# pqr3stu8vwx
#
# a1b2c3d4e5f
#
# treb7uchet
#
#
# In this example, the calibration values of these four lines are 12, 38, 15, and 77. Adding these together produces 142.
#
# Consider your entire calibration document. What is the sum of all of the calibration values?

# %%
#  Steps to get the desired answer:
#
# 1) Need to find the numbers (digits) from the string
# 2) Get the first and the last digit
# 3) Write these two digit numbers into a list
# 4) Sum the list and result is the desired outcome

# %%
import re

test_string = "There are 2 apples for 5 persons in total that is 3 people without apples"
 
# printing original string 
print("The original string : " + test_string)
 
First = int(re.findall(r'\d+', test_string)[0])
Final = int(re.findall(r'\d+', test_string)[-1])
Twodigits = First*10+Final

# print result
print("The numbers list is :",Twodigits)
# Out:
# The original string : There are 2 apples for 5 persons in total that is 3 people without apples
# The numbers list is : 23

# %%
import re

with open('Day_1_file.txt', 'r') as file:
    
    lines = []
    
    for line in file:
        line=line.strip()
        lines.append(line)

for entry in lines:
    First = int(re.findall(r'\d+', entry)[0])
    Final = int(re.findall(r'\d+', entry)[-1])
    Twodigits = First*10+Final
    number.append(Twodigits)

print(number)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 12
#       9         lines.append(line)
#      11 for entry in lines:
# ---> 12     First = int(re.findall(r'\d+', entry)[0])
#      13     Final = int(re.findall(r'\d+', entry)[-1])
#      14     Twodigits = First*10+Final
#
# IndexError: list index out of range

# %%
Number = []
for i in range(len(lines[0:-1])):
    First = int(re.findall(r'\d+', lines[i])[0])
    FirstDig = int(str(First)[0])
    Final = int(re.findall(r'\d+', lines[i])[-1])
    FinalDig = int(str(Final)[-1])
    Twodigits = FirstDig*10+FinalDig
    Number.append(Twodigits)

print(Number)
# Out:
# [33, 81, 94, 46, 71, 16, 77, 45, 22, 65, 51, 77, 33, 28, 19, 22, 11, 21, 68, 33, 44, 66, 66, 86, 88, 43, 88, 28, 88, 33, 88, 56, 92, 59, 11, 17, 22, 29, 42, 33, 66, 11, 55, 53, 66, 41, 44, 71, 11, 26, 77, 22, 24, 93, 55, 97, 85, 64, 22, 14, 79, 44, 41, 44, 64, 57, 37, 97, 77, 44, 18, 79, 99, 64, 88, 22, 66, 93, 66, 87, 45, 33, 14, 22, 17, 29, 27, 56, 96, 28, 11, 55, 11, 22, 88, 55, 54, 79, 66, 91, 53, 95, 94, 65, 98, 11, 85, 49, 88, 99, 54, 73, 69, 29, 55, 22, 62, 44, 28, 77, 11, 46, 87, 37, 68, 55, 88, 25, 65, 32, 61, 88, 95, 11, 29, 11, 88, 55, 99, 44, 84, 11, 99, 52, 28, 74, 33, 99, 33, 22, 62, 43, 84, 33, 43, 35, 64, 37, 84, 71, 44, 59, 44, 86, 33, 89, 55, 55, 92, 33, 92, 91, 22, 13, 68, 55, 97, 92, 35, 57, 54, 33, 33, 98, 63, 55, 16, 44, 55, 87, 83, 44, 11, 33, 12, 83, 22, 53, 71, 68, 43, 98, 77, 99, 47, 17, 66, 93, 83, 77, 11, 37, 49, 25, 11, 99, 66, 61, 77, 22, 76, 77, 11, 89, 59, 42, 22, 64, 64, 64, 53, 33, 19, 33, 61, 77, 66, 38, 77, 46, 44, 49, 51, 27, 55, 66, 33, 93, 98, 6
# ...

# %%
print(sum(Number))
# Out:
# 54605

# %%
with open('day_1_doc2.txt', 'r') as file:
    
    dictonary = []
    
    for line in file:
        line=line.strip()
        dictonary.append(line)
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine', '1', '2', '3', '4', '5', '6', '7', '8', '9', '']

# %%
lines = [lines.replace("one","one1one") for lines in lines]
lines = [lines.replace("two","two2two") for lines in lines]
lines = [lines.replace("three","three3three") for lines in lines]
lines = [lines.replace("four","four4four") for lines in lines]
lines = [lines.replace("five","five5five") for lines in lines]
lines = [lines.replace("six","six6six") for lines in lines]
lines = [lines.replace("seven","seven7seven") for lines in lines]
lines = [lines.replace("eight","eight8eight") for lines in lines]
lines = [lines.replace("nine","nine9nine") for lines in lines]

# %%
print(lines)
# Out:
# ['two2two2two2twovgtprdzcjjzkq3ffsbcblnpq', 'two2two2two2two8six6sixbmrmqzrrb1seven7seven', '9964pfxmmr474', '46one1one1one1one1one1one1one1one', '7fvfour4fourgkfkkblone1one1one1one1one1one1one1oneeight8eightdrfscspgkdrmzzt1', '15two2two2two2two6six6six', 'htxxfmfd7nb', 'six6sixfive5fivesix6sixeight8eight4pfsgxvn9sfjfk5', 'pmjjpggvhkrq2', 'tvbrkhlxdsnine9nine65', 'four4four5gkrptqnine9ninenbdvffour4four1z', 'four4foursgnlxmjtcrrfour4four7', '3one1one1one1one1one1one1one1onetwo2two2two2twogkhmllzvrsqzhhnkvdg', 'nine9ninenine9ninegxknqzpsix6six28', '1seven7seven85189mv', 'gtwo2two2two2twone1one1one1one1one1one1one1onejcncdlhpsxjrxnmpvfgtdrcdtd2nm', '1nine9ninemxzntjptl', 'qcmqfour4four2one1one1one1one1one1one1one1onesgplvgzkdltqtvzhtb1', 'seven7seventhree3threerxqvgkzqhfxfdhnp628zxtbjklkpdtwo2two2two2two', 'fjdsgcsqppzdthree3threefour4four3one1one1one1one1one1one1one1one3lvmpm', 'six6sixseven7sevenfive5fivefour4fourxf4mzhmkztwo2two2two2twone1one1one1one1one1one1one1onepzt', 'nine9ninen
# ...

# %%
import re

with open('Day_1_file.txt', 'r') as file:
    
    lines = []
    
    for line in file:
        line=line.strip()
        lines.append(line)

lines = [lines.replace("one","one1one") for lines in lines]
lines = [lines.replace("two","two2two") for lines in lines]
lines = [lines.replace("three","three3three") for lines in lines]
lines = [lines.replace("four","four4four") for lines in lines]
lines = [lines.replace("five","five5five") for lines in lines]
lines = [lines.replace("six","six6six") for lines in lines]
lines = [lines.replace("seven","seven7seven") for lines in lines]
lines = [lines.replace("eight","eight8eight") for lines in lines]
lines = [lines.replace("nine","nine9nine") for lines in lines]

# %%
print(lines)
# Out:
# ['two2twovgtprdzcjjzkq3ffsbcblnpq', 'two2two8six6sixbmrmqzrrb1seven7seven', '9964pfxmmr474', '46one1one', '7fvfour4fourgkfkkblone1oneeight8eightdrfscspgkdrmzzt1', '15two2two6six6six', 'htxxfmfd7nb', 'six6sixfive5fivesix6sixeight8eight4pfsgxvn9sfjfk5', 'pmjjpggvhkrq2', 'tvbrkhlxdsnine9nine65', 'four4four5gkrptqnine9ninenbdvffour4four1z', 'four4foursgnlxmjtcrrfour4four7', '3one1onetwo2twogkhmllzvrsqzhhnkvdg', 'nine9ninenine9ninegxknqzpsix6six28', '1seven7seven85189mv', 'gtwo2twone1onejcncdlhpsxjrxnmpvfgtdrcdtd2nm', '1nine9ninemxzntjptl', 'qcmqfour4four2one1onesgplvgzkdltqtvzhtb1', 'seven7seventhree3threerxqvgkzqhfxfdhnp628zxtbjklkpdtwo2two', 'fjdsgcsqppzdthree3threefour4four3one1one3lvmpm', 'six6sixseven7sevenfive5fivefour4fourxf4mzhmkztwo2twone1onepzt', 'nine9ninenine9ninesix6sixskjkbhx6nine9nineone1oneight8eightj', 'four4four6nzqxhhnrg', '86five5fiveone1one9dhrkkh6', '8nine9ninetvnsrcsbpn', 'two2two43one1one', '8vfvbrnclnmthree3three8one1onetwo2twoeight8eightthree3three', 'one1one2cz
# ...

# %%
Number = []
for i in range(len(lines[0:-1])):
    First = int(re.findall(r'\d+', lines[i])[0])
    FirstDig = int(str(First)[0])
    Final = int(re.findall(r'\d+', lines[i])[-1])
    FinalDig = int(str(Final)[-1])
    Twodigits = FirstDig*10+FinalDig
    Number.append(Twodigits)

print(Number)
# Out:
# [23, 27, 94, 41, 71, 16, 77, 65, 22, 95, 41, 47, 32, 98, 19, 22, 19, 41, 72, 33, 61, 98, 46, 86, 89, 21, 83, 11, 58, 75, 88, 76, 99, 59, 11, 67, 72, 29, 52, 63, 66, 11, 55, 53, 65, 48, 44, 31, 35, 26, 78, 62, 44, 93, 58, 91, 85, 32, 81, 14, 79, 34, 61, 44, 54, 58, 87, 93, 99, 24, 18, 79, 64, 69, 83, 28, 96, 94, 69, 87, 88, 32, 38, 27, 17, 29, 23, 56, 96, 24, 11, 78, 18, 82, 86, 57, 54, 79, 83, 92, 53, 25, 84, 69, 98, 18, 45, 49, 82, 29, 54, 53, 69, 24, 55, 22, 62, 44, 36, 74, 61, 45, 87, 38, 38, 54, 88, 65, 35, 99, 12, 88, 95, 11, 21, 11, 68, 52, 69, 69, 82, 41, 22, 52, 58, 74, 63, 23, 32, 16, 62, 43, 84, 33, 53, 15, 64, 37, 84, 71, 46, 59, 44, 86, 34, 11, 55, 44, 92, 33, 94, 91, 22, 33, 68, 65, 97, 92, 35, 57, 24, 93, 33, 98, 63, 55, 14, 48, 31, 37, 59, 99, 12, 33, 92, 53, 86, 53, 71, 68, 23, 98, 32, 99, 27, 14, 18, 93, 83, 74, 91, 73, 49, 15, 88, 11, 66, 61, 97, 26, 76, 77, 42, 87, 59, 41, 22, 64, 24, 71, 53, 93, 16, 55, 91, 77, 66, 38, 77, 46, 74, 48, 51, 97, 59, 66, 33, 23, 98, 6
# ...

# %%
print(sum(Number))
# Out:
# 55429
